# %%
import xlrd
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
from collections import OrderedDict
from openpyxl import Workbook
import os.path
from os import scandir
import os 
import pandas as pd

path = '/home/souhila/nvme-storage/data/artificial/tmp_artifical/'

# %%
tax=[]

# %%
for root, _, files in os.walk(path) :
    if len(files)>1:
        tax.append(files.split('_')[1])
        compte = {k: tax.count(k) for k in set(tax)}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b643503164b3> in <module>
#       1 for root, _, files in os.walk(path) :
#       2     if len(files)>1:
# ----> 3         tax.append(files.split('_')[1])
#       4         compte = {k: tax.count(k) for k in set(tax)}
#
# AttributeError: 'list' object has no attribute 'split'

# %%
cpt = 0
for root, _, files in os.walk(path) :
    if len(files)>=1:
        print(len(files),cpt)
        cpt+=len(files)
# Out:
# 73 0
# 78 73
# 98 151
# 79 249
# 35 328
# 77 363
# 78 440
# 70 518
# 64 588
# 36 652
# 71 688
# 71 759
# 47 830
# 87 877
# 40 964
# 93 1004
# 58 1097
# 66 1155
# 2 1221
# 41 1223
# 62 1264
# 48 1326
# 77 1374
# 29 1451
# 68 1480
# 41 1548
# 54 1589
# 52 1643
# 47 1695
# 66 1742
# 72 1808
# 70 1880
# 65 1950
# 47 2015
# 46 2062
# 30 2108
# 52 2138
# 65 2190
# 59 2255
# 64 2314
# 29 2378
# 65 2407
# 75 2472
# 47 2547
# 48 2594
# 39 2642
# 70 2681
# 76 2751
# 87 2827
# 53 2914
# 36 2967
# 23 3003
# 58 3026
# 51 3084
# 18 3135
# 71 3153
# 42 3224
# 41 3266
# 59 3307
# 67 3366
# 51 3433
# 65 3484
# 36 3549
# 38 3585
# 77 3623
# 41 3700
# 47 3741
# 48 3788
# 52 3836
# 63 3888
# 66 3951
# 52 4017
# 94 4069
# 82 4163
# 56 4245
# 59 4301
# 65 4360
# 39 4425
# 95 4464
# 44 4559
# 57 4603
# 65 4660
# 51 4725
# 59 4776
# 41 4835
# 66 4876
# 88 4942
# 70 5030
# 68 5100
# 68 5168
# 41 5236
# 80 5277
# 83 5357
# 41 5440
# 60 5481
# 56 5541
# 53 5597
# 52 5650
# 47 5702
# 74 5749
# 63 5823
# 60 5886
# 104 5946
# 41 6050
# 36 6091
# 54 6127
# 69 6181
# 53 6250
# 106 6303
# 52 6409
# 42 6461
# 36 6503
# 81 6539
# 70 6620
# 75 6690
# 36 6765
# 35 6801
# 71 6836
# 65 6907
# 71 6972
# 39 7043
# 53 7082
# 63 7135
# 24 7198
# 55 7222
# 69 7277
# 56 7346
# 70 7402
# 64 7472
# 59 7536
# 59 7595
# 61 7654
# 61 7715
# 54 7776
# 77 7830
# 47 7907
# 50 7954
# 47 8004
# 70 8051
# 92 8121
# 86 8213
# 52 8299
# 1 8351
# 52 8352
# 70 8404
# 59 8474
# 83 8533
# 75 8616
# 58 8691
# 64 8749
# 60 8813
# 47 8873
# 69 8920
# 36 8989
# 77 9025
# 57 9102
# 70 9159
# 47 9229
# 58 9276
# 52 9334
# 36 9386
# 39 9422
# 59 9461
# 42 9520
# 68 9562
# 29 9630
# 71 9659
# 86 9730
# 47 9816
