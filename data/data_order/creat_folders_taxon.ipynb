# %%
import cv2  
import numpy as np 
from PIL import ImageFilter 
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt
import random
import imutils
from os import listdir
import os 
import shutil
import pandas as pd

from sklearn.preprocessing import StandardScaler

#%run /home/souhila/Diatoms/variables.ipynb

# %%
DATASET_PATH_MISTAKE = '/home/souhila/nvme-storage/version_anciennes/atlas_RA/Tome1/tmp/' 
tableur = '/home/souhila/nvme-storage/version_anciennes/atlas_RA/Tome1/atlas_description.xlsx' 
tab = pd.read_excel(tableur, sheet_name=None)
#res = [value for value in list2 if value not in list1]
tab.names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-35cdbf06fb9f> in <module>
#       3 tab = pd.read_excel(tableur, sheet_name=None)
#       4 #res = [value for value in list2 if value not in list1]
# ----> 5 tab.names
#
# AttributeError: 'dict' object has no attribute 'names'

# %%
files = [f for f in listdir(DATASET_PATH) if os.path.isfile(os.path.join(DATASET_PATH, f))]
'''for file in files:
    if not os.path.exists(os.path.dirname(os.path.join('/home/souhila/nvme-storage/RA_V2/' + file.split('_')[1]))):
    #print(file.split('_')[1])
        os.makedirs(os.path.dirname(join('/home/souhila/nvme-storage/RA_V2/' + file.split('_')[1])))

#for file in files:
    shutil.move(os.path.join('/home/souhila/nvme-storage/RA_V2/tmp2/'+ file.split('_')[1]), join('/home/souhila/nvme-storage/RA_V2/tmp/' + file.split('_')[1]) )
'''
# Out:
# "for file in files:\n    if not os.path.exists(os.path.dirname(os.path.join('/home/souhila/nvme-storage/RA_V2/' + file.split('_')[1]))):\n    #print(file.split('_')[1])\n        os.makedirs(os.path.dirname(join('/home/souhila/nvme-storage/RA_V2/' + file.split('_')[1])))\n\n#for file in files:\n    shutil.move(os.path.join('/home/souhila/nvme-storage/RA_V2/tmp2/'+ file.split('_')[1]), join('/home/souhila/nvme-storage/RA_V2/tmp/' + file.split('_')[1]) )\n"

# %%
a=[]
for file in files:
    a.append(file.split('_')[1])

# %%
a
# Out:
# ['PUBA',
#  'DMON',
#  'CLNT',
#  'PUBA',
#  'AUGR',
#  'DMON',
#  'PLBI',
#  'ADEX',
#  'EUFL',
#  'PHEL',
#  'PUGL',
#  'PDAO',
#  'PLHU',
#  'CEUG',
#  'ADEG',
#  'PLAU',
#  'DMON',
#  'COCE',
#  'PSAT',
#  'CEUG',
#  'ACLI',
#  'ADEG',
#  'CTWE',
#  'AUAJ',
#  'PTDU',
#  'DPST',
#  'SHAN',
#  'DMON',
#  'LHUN',
#  'PTCO',
#  'ADEU',
#  'DMON',
#  'COPS',
#  'PTLA',
#  'ADLA',
#  'COCE',
#  'ACLI',
#  'DMON',
#  'DMON',
#  'CNTH',
#  'COCE',
#  'DMON',
#  'DPST',
#  'SHAN',
#  'ACLI',
#  'PSRE',
#  'PLAU',
#  'ADNM',
#  'ANMN',
#  'PSRE',
#  'PDAU',
#  'EUFL',
#  'CMED',
#  'PSRE',
#  'ADSU',
#  'ADTR',
#  'COPL',
#  'PDAO',
#  'PDAO',
#  'AUTE',
#  'CATO',
#  'CCOS',
#  'DMON',
#  'CDTG',
#  'COPL',
#  'TGES',
#  'DPST',
#  'CEUO',
#  'ADGL',
#  'PSAT',
#  'PLAU',
#  'ADLA',
#  'CLNT',
#  'CPED',
#  'CDTG',
#  'CAGR',
#  'PSRE',
#  'ADNM',
#  'CLNT',
#  'ADSU',
#  'PDAO',
#  'AUGR',
#  'CDTG',
#  'ADGL',
#  'PACA',
#  'CCOS',
#  'PTLA',
#  'ADEG',
#  'ADSU',
#  'DMON',
# ...

# %%
def check_dirs(filename):
    if not os.path.exists(os.path.dirname(filename)):
        try:
            os.makedirs(os.path.dirname(filename))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
    
def get_selected_taxons(file_path, inv=False):
    selected_taxons = {}
    f = open(file_path, 'r') 
    lines = f.readlines() 
    del lines[0]
    for line in lines:
        line = line.strip()
        taxon, taxon_id = line.split(',')[0], int(line.split(',')[1])
        selected_taxons[taxon] = taxon_id
    if inv:
        return {v: k for k, v in selected_taxons.items()} 
    else:
        return selected_taxons
    
def delete_all_files_in_folder(folder):
    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
files = [f for f in listdir(DATASET_PATH) if isfile(join(DATASET_PATH, f))]
for file in files:
    DATASET_PATH_img = join(DATASET_PATH_ROOT + '/' + file)

    angle = random.randint(0,180)
    print(angle)
    #img, mask_rot, mask_erod, fond_moyen = rot_image_path(DATASET_PATH,angle)
    img = cv2.imread(DATASET_PATH_img,cv2.COLOR_BGR2GRAY)
    zslack = flou_plane(img,alpha=10 )
    angle = random.randint(0,90)
    print(angle)

    for i in range(6):
        img = rot_image_img(zslack[i],angle)
    #p = plt.imshow(Image.fromarray(img))
    #plt.show()
