# %%
import cv2  
import numpy as np 
from PIL import ImageFilter 
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt
import random
import imutils
from os import listdir
import os 
import shutil

from sklearn.preprocessing import StandardScaler

#%run /home/souhila/Diatoms/variables.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Diatoms/variables.ipynb in <module>
# ----> 1 home/souhila/nvme-storage/RA_V2/tmp/RA_AAMB_0012.png()
#
# NameError: name 'home' is not defined

# %%
join('/home/souhila/nvme-storage/RA_V2/tmp2/' + file.split('_')[1])
# Out:
# '/home/souhila/nvme-storage/RA_V2/tmp2/NSPD'

# %%
files = [f for f in listdir(DATASET_PATH) if isfile(join(DATASET_PATH, f))]
for file in files:
    if not os.path.exists(os.path.dirname(join('/home/souhila/nvme-storage/RA_V2/' + file.split('_')[1]))):
    #print(file.split('_')[1])
        os.makedirs(os.path.dirname(join('/home/souhila/nvme-storage/RA_V2/' + file.split('_')[1])))

for file in files:
    shutil.move(join('/home/souhila/nvme-storage/RA_V2/tmp2/'+ file.split('_')[1]), join('/home/souhila/nvme-storage/RA_V2/tmp/' + file.split('_')[1]) )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /mnt/nvme-storage/venv/tf2.1/lib/python3.6/shutil.py in move(src, dst, copy_function)
#     549     try:
# --> 550         os.rename(src, real_dst)
#     551     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/souhila/nvme-storage/RA_V2/tmp' -> '/home/souhila/nvme-storage/RA_V2/tmp2/NSPD'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-b0174f42bb2e> in <module>
#       6
#       7 for file in files:
# ----> 8     shutil.move('/home/souhila/nvme-storage/RA_V2/tmp', join('/home/souhila/nvme-storage/RA_V2/tmp2/' + file.split('_')[1]) )
#
# /mnt/nvme-storage/venv/tf2.1/lib/python3.6/shutil.py in move(src, dst, copy_function)
#     562             rmtree(src)
#     563         else:
# --> 564             copy_function(src, real_dst)
#     565             os.unlink(src)
#     566     return real_dst
#
# /mnt/nvme-storage/venv/tf2.1/lib/python3.6/shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# /mnt/nvme-storage/venv/tf2.1/lib/python3.6/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/souhila/nvme-storage/RA_V2/tmp'

# %%
files
# Out:
# ['RA_FAPO_0240.png',
#  'RA_NSPD_0658.png',
#  'RA_GOMS_2201.png',
#  'RA_PUBA_0330.png',
#  'RA_DMON_0549.png',
#  'RA_NDBF_1027.png',
#  'RA_CLNT_1120.png',
#  'RA_PUBA_0326.png',
#  'RA_GMIN_1562.png',
#  'RA_AUGR_0037.png',
#  'RA_GVRD_2071.png',
#  'RA_GPRO_1775.png',
#  'RA_GMIC_1474.png',
#  'RA_CTRO_0368.png',
#  'RA_ADMM_0038.png',
#  'RA_GPAR_1717.png',
#  'RA_DMON_0555.png',
#  'RA_BNEG_0138.png',
#  'RA_NRCH_0822.png',
#  'RA_PLBI_1359.png',
#  'RA_LMUT_0878.png',
#  'RA_ADEX_0684.png',
#  'RA_NCTV_0071.png',
#  'RA_FAUT_0283.png',
#  'RA_EUFL_1255.png',
#  'RA_CNCI_0271.png',
#  'RA_GELG_1289.png',
#  'RA_FAUT_0276.png',
#  'RA_GTER_1987.png',
#  'RA_CBAM_0450.png',
#  'RA_DMES_0119.png',
#  'RA_GCLA_1169.png',
#  'RA_PHEL_1572.png',
#  'RA_FSBH_0602.png',
#  'RA_PUGL_0339.png',
#  'RA_PMDA_0954.png',
#  'RA_HLMO_0850.png',
#  'RA_EARB_0863.png',
#  'RA_PDAO_1541.png',
#  'RA_ADMS_0019.png',
#  'RA_FGRA_0325.png',
#  'RA_PLHU_1506.png',
#  'RA_GPRI_1843.png',
#  'RA_CEUG_1071.png',
#  'RA_GEXL_1343.png',
#  'RA_EMRO_0825.png',
#  'RA_FPEC_0449.png',
#  'RA_GPRI_1867.png',
#  'RA_GPAR_1746.png',
#  'RA_ADEG_0652.png',
#  'RA_UCAP_0833.png',
#  'RA_FFBI_0532.png',
#  'RA_GOMS_2213.png',
#  'RA_GCUN_1230.png',
#  'RA_PIAN_0903.png',
#  'RA_CMOL_0202.png',
#  'RA_SSTM_1271.png',
#  'RA_PLAU_1614.png',
#  'RA_DMON_1012.png',
#  'RA_COCE_0235.png',
#  'RA_CAMP_0172.png',
#  'RA_SPUP_1215.png',
#  'RA_PSAT_1651.png',
#  'RA_TVEN_0802.png',
#  'RA_AFOR_0015.png',
#  'RA_HLMO_0855.png',
#  'RA_DMON_0143.png',
#  'RA_CEUG_1078.png',
#  'RA_NXAS_0059.png',
#  'RA_ACLI_0796.png',
#  'RA_DANC_0043.png',
#  'RA_NCTO_0270.png',
#  'RA_GYKU_0756.png',
#  'RA_ADEG_0664.png',
#  'RA_GTRU_2020.png',
#  'RA_CTWE_0076.png',
#  'RA_EEXI_0920.png',
#  'RA_FRCP_0526.png',
#  'RA_NESC_0326.png',
#  'RA_AUAJ_0022.png',
#  'RA_FNEV_0371.png',
#  'RA_NVIP_0804.png',
#  'RA_GTER_1961.png',
#  'RA_NANT_0032.png',
#  'RA_PTDU_1385.png',
#  'RA_DPST_0280.png',
#  'RA_AVTU_0111.png',
#  'RA_EOCO_0459.png',
#  'RA_SHAN_0375.png',
#  'RA_GSTA_1919.png',
#  'RA_AOVA_0052.png',
#  'RA_NGER_0347.png',
#  'RA_DMON_0990.png',
#  'RA_GOMS_2104.png',
#  'RA_LHUN_1336.png',
#  'RA_CALS_0229.png',
#  'RA_EMIN_0975.png',
#  'RA_PTCO_1483.png',
#  'RA_LGOE_0873.png',
#  'RA_AVTU_0094.png',
#  'RA_ADEU_0630.png',
#  'RA_NREI_0552.png',
#  'RA_RSIN_2322.png',
#  'RA_GAGV_1055.png',
#  'RA_DVLN_0215.png',
#  'RA_PBSC_0917.png',
#  'RA_LGOE_0853.png',
#  'RA_DANC_0038.png',
#  'RA_LVCF_0944.png',
#  'RA_DMON_0982.png',
#  'RA_GAGV_1086.png',
#  'RA_PPSC_0683.png',
#  'RA_HCAP_0824.png',
#  'RA_CSLP_0342.png',
#  'RA_ENMI_0605.png',
#  'RA_DMES_0096.png',
#  'RA_NTPT_0721.png',
#  'RA_COPS_1164.png',
#  'RA_GCLF_1130.png',
#  'RA_GSTA_1924.png',
#  'RA_PTLA_1450.png',
#  'RA_FGRA_0330.png',
#  'RA_GTER_2001.png',
#  'RA_NTRV_0726.png',
#  'RA_GOMS_2138.png',
#  'RA_DOBL_0377.png',
#  'RA_LUPS_0969.png',
#  'RA_ADLA_0762.png',
#  'RA_GLGN_1372.png',
#  'RA_GOMS_2164.png',
#  'RA_GCUN_1205.png',
#  'RA_COCE_0234.png',
#  'RA_GCUV_1249.png',
#  'RA_FPEC_0476.png',
#  'RA_GELG_1300.png',
#  'RA_SRAD_1184.png',
#  'RA_ACLI_0789.png',
#  'RA_FNEV_0377.png',
#  'RA_EEXI_0924.png',
#  'RA_DPAR_0414.png',
#  'RA_PULA_0721.png',
#  'RA_SSMB_1354.png',
#  'RA_ETEN_1017.png',
#  'RA_FPRU_0410.png',
#  'RA_DMON_0501.png',
#  'RA_ABRY_0004.png',
#  'RA_DANC_0037.png',
#  'RA_GTER_1980.png',
#  'RA_NCTT_0200.png',
#  'RA_CLCT_0196.png',
#  'RA_PSNF_1045.png',
#  'RA_GOLC_1682.png',
#  'RA_PSBV_1018.png',
#  'RA_CYMS_0438.png',
#  'RA_ENMI_0614.png',
#  'RA_FCRS_0679.png',
#  'RA_DMON_0573.png',
#  'RA_FPEL_0640.png',
#  'RA_CNTH_1160.png',
#  'RA_GLGN_1390.png',
#  'RA_CMLF_0304.png',
#  'RA_LVCF_0926.png',
#  'RA_DOCU_0380.png',
#  'RA_BNEG_0114.png',
#  'RA_NUSA_0754.png',
#  'RA_COCE_0226.png',
#  'RA_HCAP_0800.png',
#  'RA_NCTO_0280.png',
#  'RA_NAAM_0008.png',
#  'RA_GMEX_1447.png',
#  'RA_DMON_0843.png',
#  'RA_CSBH_0309.png',
#  'RA_CAEX_0173.png',
#  'RA_GAGC_1020.png',
#  'RA_GVRD_2068.png',
#  'RA_DMON_0167.png',
#  'RA_CLTL_0229.png',
#  'RA_GDEC_0749.png',
#  'RA_GELG_1285.png',
#  'RA_CSIL_0213.png',
#  'RA_CSLP_0344.png',
#  'RA_DPST_0285.png',
#  'RA_SHAN_0378.png',
#  'RA_GAGV_1075.png',
#  'RA_GYOB_0761.png',
#  'RA_NCTT_0191.png',
#  'RA_ACLI_0782.png',
#  'RA_GCBC_1261.png',
#  'RA_PSRE_1630.png',
#  'RA_ESUM_0808.png',
#  'RA_APED_0075.png',
#  'RA_PLAU_1613.png',
#  'RA_ADNM_0860.png',
#  'RA_PMNF_0955.png',
#  'RA_GPSA_1814.png',
#  'RA_GLGN_1395.png',
#  'RA_FSAP_0629.png',
#  'RA_TFLO_0790.png',
#  'RA_GMIN_1506.png',
#  'RA_NRAD_0505.png',
#  'RA_ANMN_0003.png',
#  'RA_ESLE_0666.png',
#  'RA_PSRE_1627.png',
#  'RA_CSMU_0259.png',
#  'RA_PDAU_1373.png',
#  'RA_LVCF_0934.png',
#  'RA_EUFL_1253.png',
#  'RA_DOCU_0384.png',
#  'RA_EVUL_0721.png',
#  'RA_CMED_0245.png',
#  'RA_DOCU_0391.png',
#  'RA_CSMU_0258.png',
#  'RA_PSRE_1632.png',
#  'RA_HNOR_0862.png',
#  'RA_NCAT_0165.png',
#  'RA_PPRS_0670.png',
#  'RA_SSEM_1247.png',
#  'RA_CTRO_0379.png',
#  'RA_RSIN_2306.png',
#  'RA_GDEC_0730.png',
#  'RA_ADSU_0964.png',
#  'RA_NDBF_1022.png',
#  'RA_CAPR_0131.png',
#  'RA_ADTR_1019.png',
#  'RA_PPSA_1125.png',
#  'RA_FAUT_0269.png',
#  'RA_CLTL_0239.png',
#  'RA_LVCF_0941.png',
#  'RA_PPLC_1112.png',
#  'RA_FSAP_0628.png',
#  'RA_HIPS_0833.png',
#  'RA_STKR_1310.png',
#  'RA_COPL_1211.png',
#  'RA_MCIR_0596.png',
#  'RA_PDAO_1560.png',
#  'RA_NVIP_0799.png',
#  'RA_NCTV_0068.png',
#  'RA_CCMP_0140.png',
#  'RA_HCAP_0792.png',
#  'RA_PDAO_1561.png',
#  'RA_AUTE_0068.png',
#  'RA_FPEC_0439.png',
#  'RA_ASPH_0057.png',
#  'RA_CATO_0126.png',
#  'RA_NANT_0036.png',
#  'RA_ETEN_1013.png',
#  'RA_CEXF_0199.png',
#  'RA_DICG_0226.png',
#  'RA_DICG_0220.png',
#  'RA_HLMO_0853.png',
#  'RA_CCOS_0138.png',
#  'RA_EOMI_0495.png',
#  'RA_CRAC_0266.png',
#  'RA_AFOR_0002.png',
#  'RA_PSIN_0992.png',
#  'RA_GELG_1309.png',
#  'RA_MCIR_0601.png',
#  'RA_AFOR_0014.png',
#  'RA_ENVE_0719.png',
#  'RA_NASP_0843.png',
#  'RA_ECPM_0774.png',
#  'RA_DMON_0593.png',
#  'RA_ENMI_0571.png',
#  'RA_NNOV_0463.png',
#  'RA_CDTG_0180.png',
#  'RA_PSNF_1059.png',
#  'RA_LMUT_0879.png',
#  'RA_GMIC_1467.png',
#  'RA_NRCH_0519.png',
#  'RA_COPL_1207.png',
#  'RA_NREI_0562.png',
#  'RA_MCCO_0632.png',
#  'RA_FSBH_0615.png',
#  'RA_NRHY_0573.png',
#  'RA_GVRD_2078.png',
#  'RA_FVAU_0493.png',
#  'RA_DMON_0163.png',
#  'RA_FVUC_0690.png',
#  'RA_NESP_1081.png',
#  'RA_AVTU_0099.png',
#  'RA_HCAP_0813.png',
#  'RA_GOMS_2143.png',
#  'RA_NCTV_0070.png',
#  'RA_AMID_0020.png',
#  'RA_CLCT_0173.png',
#  'RA_GADC_0986.png',
#  'RA_FCRO_0293.png',
#  'RA_RSIN_2320.png',
#  'RA_APED_0085.png',
#  'RA_NCTO_0292.png',
#  'RA_FSBH_0612.png',
#  'RA_DOCU_0410.png',
#  'RA_TGES_0436.png',
#  'RA_GAGV_1066.png',
#  'RA_FSAP_0624.png',
#  'RA_RSIN_2288.png',
#  'RA_DPST_0283.png',
#  'RA_GACU_1009.png',
#  'RA_BNEG_0098.png',
#  'RA_FMES_0345.png',
#  'RA_HCAP_0811.png',
#  'RA_NCTV_0075.png',
#  'RA_CEUO_1090.png',
#  'RA_ADGL_0728.png',
#  'RA_PSAT_1661.png',
#  'RA_GCLF_1140.png',
#  'RA_PLAU_1587.png',
#  'RA_GEXL_1341.png',
#  'RA_NVEN_0779.png',
#  'RA_NTPT_0715.png',
#  'RA_TFAS_0806.png',
#  'RA_SRAD_1189.png',
#  'RA_GELG_1325.png',
#  'RA_PSBV_1012.png',
#  'RA_ADLA_0771.png',
#  'RA_CBFI_0234.png',
#  'RA_DOBL_0358.png',
#  'RA_CAMP_0169.png',
#  'RA_GEVA_0971.png',
#  'RA_NPSA_0492.png',
#  'RA_NEAM_1041.png',
#  'RA_DICG_0224.png',
#  'RA_GMIN_1523.png',
#  'RA_GMEX_1443.png',
#  'RA_FPEC_0467.png',
#  'RA_CYMS_0445.png',
#  'RA_NASP_0854.png',
#  'RA_CLNT_1128.png',
#  'RA_CSLP_0346.png',
#  'RA_CPED_1170.png',
#  'RA_CDTG_0178.png',
#  'RA_NAAN_0014.png',
#  'RA_CAGR_0129.png',
#  'RA_CALS_0226.png',
#  'RA_PISS_0944.png',
#  'RA_CNLP_0291.png',
#  'RA_GMIC_1453.png',
#  'RA_ECKR_0762.png',
#  'RA_NULA_1086.png',
#  'RA_PSRE_1646.png',
#  'RA_PSBR_0653.png',
#  'RA_CVVA_0252.png',
#  'RA_DDEL_0549.png',
#  'RA_CBNA_0495.png',
#  'RA_NCTO_0277.png',
#  'RA_ENMI_0611.png',
#  'RA_SSMI_1337.png',
#  'RA_CEXF_0204.png',
#  'RA_SSVH_1332.png',
#  'RA_GPRI_1879.png',
#  'RA_NASP_0837.png',
#  'RA_EOMI_0483.png',
#  'RA_HLMO_0832.png',
#  'RA_AFOR_0000.png',
#  'RA_CRAC_0267.png',
#  'RA_NTRI_0691.png',
#  'RA_ADNM_0864.png',
#  'RA_CLNT_1107.png',
#  'RA_ADSU_0966.png',
#  'RA_NEAF_1034.png',
#  'RA_GOLC_1704.png',
#  'RA_BNEG_0124.png',
#  'RA_GOLC_1700.png',
#  'RA_PDAO_1558.png',
#  'RA_AUGR_0027.png',
#  'RA_ECPM_0797.png',
#  'RA_ENMI_0592.png',
#  'RA_ABRY_0003.png',
#  'RA_NGER_0353.png',
#  'RA_DIPS_0456.png',
#  'RA_ENMI_0594.png',
#  'RA_PSCM_1052.png',
#  'RA_GCLA_1162.png',
#  'RA_CBPS_0501.png',
#  'RA_CDTG_0191.png',
#  'RA_GCUN_1227.png',
#  'RA_EICD_0949.png',
#  'RA_FHEL_0528.png',
#  'RA_ADGL_0714.png',
#  'RA_STAK_1366.png',
#  'RA_GOMS_2100.png',
#  'RA_NASP_0850.png',
#  'RA_GPRI_1881.png',
#  'RA_NSIA_0625.png',
#  'RA_PACA_1050.png',
#  'RA_CLCT_0178.png',
#  'RA_CCOS_0140.png',
#  'RA_ETEN_0998.png',
#  'RA_GPHQ_2228.png',
#  'RA_PTLA_1474.png',
#  'RA_ADEG_0667.png',
#  'RA_GOMS_2180.png',
#  'RA_ADSU_0959.png',
#  'RA_NREI_0553.png',
#  'RA_GCLF_1117.png',
#  'RA_BRUT_0083.png',
#  'RA_CHCN_0467.png',
#  'RA_GSTA_1914.png',
#  'RA_PSBR_0635.png',
#  'RA_FAUT_0277.png',
#  'RA_HVEN_0894.png',
#  'RA_DMON_0820.png',
#  'RA_NULA_1097.png',
#  'RA_LVCF_0956.png',
#  'RA_KCLE_1287.png',
#  'RA_PSAT_1667.png',
#  'RA_PSAT_1662.png',
#  'RA_GCLF_1143.png',
#  'RA_CLTL_0238.png',
#  'RA_BNEG_0116.png',
#  'RA_PBIO_1516.png',
#  'RA_NCRY_0234.png',
#  'RA_DGEM_0350.png',
#  'RA_GVRD_2066.png',
#  'RA_DMON_0147.png',
#  'RA_MAFO_0995.png',
#  'RA_CSHU_0203.png',
#  'RA_BNEG_0120.png',
#  'RA_CEUG_1069.png',
#  'RA_GLGN_1393.png',
#  'RA_GVST_2044.png',
#  'RA_EBOT_0904.png',
#  'RA_DMON_0156.png',
#  'RA_PDAO_1538.png',
#  'RA_GLAT_1433.png',
#  'RA_DMON_0907.png',
#  'RA_NAAM_0010.png',
#  'RA_PPSC_0681.png',
#  'RA_GOMS_2135.png',
#  'RA_ADSU_0935.png',
#  'RA_BNEG_0125.png',
#  'RA_DCOF_0309.png',
#  'RA_DVUL_0194.png',
#  'RA_NCAT_0152.png',
#  'RA_GPAR_1739.png',
#  'RA_ADTR_1022.png',
#  'RA_NKOT_0408.png',
#  'RA_GAGC_1021.png',
#  'RA_NEXI_0341.png',
#  'RA_GLAT_1417.png',
#  'RA_NTCX_0745.png',
#  'RA_ABRY_0010.png',
#  'RA_ADMS_0022.png',
#  'RA_DCOT_0344.png',
#  'RA_EOCO_0466.png',
#  'RA_EMIN_0968.png',
#  'RA_HVEN_0895.png',
#  'RA_FFBI_0531.png',
#  'RA_NSTL_0667.png',
#  'RA_SSEM_1230.png',
#  'RA_NVIP_0803.png',
#  'RA_CAPR_0123.png',
#  'RA_GOMS_2127.png',
#  'RA_NDCA_1074.png',
#  'RA_STOV_0777.png',
#  'RA_CINV_0116.png',
#  'RA_GOMS_2123.png',
#  'RA_STMI_0429.png',
#  'RA_ADLA_0763.png',
#  'RA_ADNM_0866.png',
#  'RA_FPRU_0388.png',
#  'RA_NESP_1084.png',
#  'RA_CYMS_0434.png',
#  'RA_GCBC_1282.png',
#  'RA_ECPM_0785.png',
#  'RA_PITE_1152.png',
#  'RA_PDAU_1379.png',
#  'RA_GPAR_1732.png',
#  'RA_PTLA_1463.png',
#  'RA_ADAM_0523.png',
#  'RA_DMON_0604.png',
#  'RA_PUOB_1162.png',
#  'RA_FDEL_0308.png',
#  'RA_CTRO_0384.png',
#  'RA_CCOC_0236.png',
#  'RA_EUFL_1254.png',
#  'RA_ABRY_0011.png',
#  'RA_DDEL_0533.png',
#  'RA_HTHU_0908.png',
#  'RA_DMON_0972.png',
#  'RA_DMON_0606.png',
#  'RA_PIAN_0904.png',
#  'RA_DDEL_0535.png',
#  'RA_AMJA_0462.png',
#  'RA_ADLA_0766.png',
#  'RA_NKOT_0412.png',
#  'RA_NTRV_0727.png',
#  'RA_ECKR_0767.png',
#  'RA_DMON_0912.png',
#  'RA_GLAT_1420.png',
#  'RA_FSBH_0604.png',
#  'RA_NCTO_0283.png',
#  'RA_GOMS_2184.png',
#  'RA_FNEV_0382.png',
#  'RA_LHUN_1331.png',
#  'RA_SSVH_1330.png',
#  'RA_HCAP_0786.png',
#  'RA_GRHB_1885.png',
#  'RA_MCIR_0590.png',
#  'RA_ENVE_0711.png',
#  'RA_PLHU_1508.png',
#  'RA_CSHU_0205.png',
#  'RA_PSIN_0990.png',
#  'RA_HPDA_0826.png',
#  'RA_GCLF_1132.png',
#  'RA_FPEC_0459.png',
#  'RA_DMES_0113.png',
#  'RA_GLGN_1387.png',
#  'RA_ADMS_0026.png',
#  'RA_NCTE_0260.png',
#  'RA_NVEN_0786.png',
#  'RA_PITE_1153.png',
#  'RA_ADMS_0027.png',
#  'RA_NBIS_1044.png',
#  'RA_SSVH_1329.png',
#  'RA_ECES_0733.png',
#  'RA_GELG_1313.png',
#  'RA_CASP_0137.png',
#  'RA_ENMI_0582.png',
#  'RA_ECAE_0563.png',
#  'RA_NDCM_1009.png',
#  'RA_SKPO_0359.png',
#  'RA_GOMS_2194.png',
#  'RA_NCTE_0252.png',
#  'RA_NRAD_0506.png',
#  'RA_CLTL_0230.png',
#  'RA_CTGL_0406.png',
#  'RA_NCRY_0232.png',
#  'RA_GCBC_1278.png',
#  'RA_FCRO_0291.png',
#  'RA_CDTG_0186.png',
#  'RA_FRCP_0525.png',
#  'RA_NAAM_0012.png',
#  'RA_ESLE_0653.png',
#  'RA_CSLP_0334.png',
#  'RA_GPRO_1749.png',
#  'RA_PLAT_0950.png',
#  'RA_BBRE_0089.png',
#  'RA_CMEN_0200.png',
#  'RA_GPRI_1821.png',
#  'RA_GACC_0705.png',
#  'RA_SBND_0744.png',
#  'RA_NREI_0558.png',
#  'RA_ADLA_0753.png',
#  'RA_GADC_1003.png',
#  'RA_GOLD_1571.png',
#  'RA_MCCO_0621.png',
#  'RA_KCLE_1283.png',
#  'RA_COCE_0225.png',
#  'RA_ADEU_0629.png',
#  'RA_DMON_0505.png',
#  'RA_GOMS_2162.png',
#  'RA_DMON_0150.png',
#  'RA_PDAO_1543.png',
#  'RA_EUFL_1258.png',
#  'RA_DICG_0234.png',
#  'RA_NVEN_0769.png',
#  'RA_FPRU_0389.png',
#  'RA_CRBU_0286.png',
#  'RA_CLTL_0231.png',
#  'RA_GOLL_1616.png',
#  'RA_KCLE_1276.png',
#  'RA_PLLN_0952.png',
#  'RA_GPLI_2240.png',
#  'RA_PPSC_0686.png',
#  'RA_ADNM_0861.png',
#  'RA_SHAN_0372.png',
#  'RA_GAGU_1034.png',
#  'RA_AVTU_0098.png',
#  'RA_SSMI_1352.png',
#  'RA_BRUT_0078.png',
#  'RA_ECPM_0786.png',
#  'RA_EMIN_0962.png',
#  'RA_PAML_0896.png',
#  'RA_CSIL_0219.png',
#  'RA_DHMA_0084.png',
#  'RA_EOMI_0488.png',
#  'RA_PINS_1080.png',
#  'RA_SSEM_1261.png',
#  'RA_RSIN_2304.png',
#  'RA_GMIN_1509.png',
#  'RA_DMON_0888.png',
#  'RA_BNEG_0106.png',
#  'RA_ADCT_0541.png',
#  'RA_GOMS_2159.png',
#  'RA_ADRI_0809.png',
#  'RA_FAPO_0252.png',
#  'RA_ECES_0740.png',
#  'RA_NANT_0026.png',
#  'RA_GOMS_2176.png',
#  'RA_CBPS_0505.png',
#  'RA_GCLF_1125.png',
#  'RA_CNDI_1130.png',
#  'RA_LHUN_1329.png',
#  'RA_PLAU_1600.png',
#  'RA_DPST_0274.png',
#  'RA_CASP_0136.png',
#  'RA_NDMB_1031.png',
#  'RA_PBIO_1531.png',
#  'RA_PSAT_1656.png',
#  'RA_NCTT_0181.png',
#  'RA_NTRI_0695.png',
#  'RA_CDUB_0099.png',
#  'RA_CAMB_0277.png',
#  'RA_GRHB_1896.png',
#  'RA_CBAM_0457.png',
#  'RA_CCMP_0151.png',
#  'RA_GELG_1308.png',
#  'RA_APED_0069.png',
#  'RA_AAMB_0010.png',
#  'RA_CLNT_1100.png',
#  'RA_DDEL_0530.png',
#  'RA_AUGA_0044.png',
#  'RA_COPL_1225.png',
#  'RA_GOMS_2112.png',
#  'RA_GCUN_1201.png',
#  'RA_DANC_0035.png',
#  'RA_NCTV_0069.png',
#  'RA_NTRV_0725.png',
#  'RA_PLIG_1105.png',
#  'RA_NULA_1092.png',
#  'RA_CVVA_0254.png',
#  'RA_CNDI_1138.png',
#  'RA_GCAP_1151.png',
#  'RA_ENVE_0704.png',
#  'RA_PUGL_0345.png',
#  'RA_HSMO_0863.png',
#  'RA_NVEN_0766.png',
#  'RA_ADEG_0666.png',
#  'RA_NDCM_1008.png',
#  'RA_DMON_0515.png',
#  'RA_NGRE_0373.png',
#  'RA_GOLI_1648.png',
#  'RA_GOMS_2144.png',
#  'RA_CMLF_0300.png',
#  'RA_FFVI_0554.png',
#  'RA_GOLI_1642.png',
#  'RA_ESBM_0499.png',
#  'RA_NTPT_0706.png',
#  'RA_DMON_0893.png',
#  'RA_GTER_1995.png',
#  'RA_AMJA_0477.png',
#  'RA_HCAP_0790.png',
#  'RA_GCBC_1258.png',
#  'RA_NSPD_0650.png',
#  'RA_NNOV_0474.png',
#  'RA_NGRE_0390.png',
#  'RA_GADC_1000.png',
#  'RA_ADAM_0534.png',
#  'RA_ADLA_0767.png',
#  'RA_LVCF_0922.png',
#  'RA_BNEG_0139.png',
#  'RA_GMIN_1504.png',
#  'RA_NNOV_0467.png',
#  'RA_FPEC_0430.png',
#  'RA_PSCM_1051.png',
#  'RA_DHMA_0077.png',
#  'RA_NEDU_1048.png',
#  'RA_PAPR_1132.png',
#  'RA_GPRI_1852.png',
#  'RA_GPRO_1756.png',
#  'RA_FAPO_0255.png',
#  'RA_PLAS_1147.png',
#  'RA_NROS_0586.png',
#  'RA_HARC_0563.png',
#  'RA_CPED_1175.png',
#  'RA_DMON_0510.png',
#  'RA_CAEX_0170.png',
#  'RA_DMON_0491.png',
#  'RA_RSIN_2276.png',
#  'RA_NTRI_0678.png',
#  'RA_FGRA_0324.png',
#  'RA_NTCX_0747.png',
#  'RA_GRHB_1902.png',
#  'RA_PLAS_1145.png',
#  'RA_ADNM_0859.png',
#  'RA_GPAR_1712.png',
#  'RA_ENVE_0708.png',
#  'RA_LUPS_0970.png',
#  'RA_GPLI_2249.png',
#  'RA_CCMP_0150.png',
#  'RA_GVST_2060.png',
#  'RA_CCMP_0149.png',
#  'RA_ADLA_0744.png',
#  'RA_PAPR_1125.png',
#  'RA_GDEC_0739.png',
#  'RA_ECTG_0913.png',
#  'RA_FVAU_0487.png',
#  'RA_HTHU_0910.png',
#  'RA_COPL_1208.png',
#  'RA_GCLA_1180.png',
#  'RA_PSBR_0644.png',
#  'RA_MCCO_0618.png',
#  'RA_ADMS_0020.png',
#  'RA_CPOL_0257.png',
#  'RA_GPLI_2238.png',
#  'RA_ESBM_0507.png',
#  'RA_MAFO_0994.png',
#  'RA_GVST_2053.png',
#  'RA_CNDI_1133.png',
#  'RA_PTCO_1480.png',
#  'RA_HLMO_0852.png',
#  'RA_GPRI_1866.png',
#  'RA_TFAS_0817.png',
#  'RA_ADLA_0754.png',
#  'RA_GRHB_1904.png',
#  'RA_NASP_0864.png',
#  'RA_CLTL_0241.png',
#  'RA_DMON_0138.png',
#  'RA_GTER_1992.png',
#  'RA_FAMO_0665.png',
#  'RA_MAFO_0996.png',
#  'RA_ADEU_0645.png',
#  'RA_DITE_0185.png',
#  'RA_NLIB_0244.png',
#  'RA_GDRU_1115.png',
#  'RA_CLTL_0223.png',
#  'RA_GMMI_0977.png',
#  'RA_ADSU_0957.png',
#  'RA_ADEU_0647.png',
#  'RA_ADLA_0758.png',
#  'RA_NTPT_0711.png',
#  'RA_TFAS_0809.png',
#  'RA_NNOT_0454.png',
#  'RA_CSLP_0324.png',
#  'RA_GCBC_1271.png',
#  'RA_GMIC_1456.png',
#  'RA_ENVE_0684.png',
#  'RA_NRAD_0497.png',
#  'RA_FRCP_0529.png',
#  'RA_DMON_0509.png',
#  'RA_CTGL_0404.png',
#  'RA_EMIN_0978.png',
#  'RA_FSBH_0590.png',
#  'RA_GAGV_1068.png',
#  'RA_NESC_0322.png',
#  'RA_ADRI_0805.png',
#  'RA_BBRE_0091.png',
#  'RA_NGOT_0358.png',
#  'RA_NASP_0842.png',
#  'RA_PTLA_1447.png',
#  'RA_STKR_1309.png',
#  'RA_LMUT_0887.png',
#  'RA_GVST_2055.png',
#  'RA_EULA_1272.png',
#  'RA_OBIC_1109.png',
#  'RA_DHMA_0074.png',
#  'RA_PPSC_0677.png',
#  'RA_LUPS_0971.png',
#  'RA_GOLD_1569.png',
#  'RA_SLEP_0764.png',
#  'RA_GLAT_1429.png',
#  'RA_BNEG_0128.png',
#  'RA_HNOR_0860.png',
#  'RA_CDTG_0184.png',
#  'RA_NJAK_0400.png',
#  'RA_GADC_0996.png',
#  'RA_TFLO_0787.png',
#  'RA_SPDB_1198.png',
#  'RA_ADGL_0742.png',
#  'RA_GOLD_1595.png',
#  'RA_GDEC_0732.png',
#  'RA_NLAN_0427.png',
#  'RA_ADGL_0738.png',
#  'RA_FDEL_0311.png',
#  'RA_GVST_2050.png',
#  'RA_APED_0074.png',
#  'RA_NRCH_0824.png',
#  'RA_DMES_0099.png',
#  'RA_GCBC_1274.png',
#  'RA_BNEG_0155.png',
#  'RA_DDEL_0534.png',
#  'RA_GLAT_1425.png',
#  'RA_HVEN_0886.png',
#  'RA_CCOC_0242.png',
#  'RA_NSBN_0675.png',
#  'RA_ACLI_0783.png',
#  'RA_GOLD_1596.png',
#  'RA_CNLP_0282.png',
#  'RA_ADSU_0953.png',
#  'RA_PAPR_1123.png',
#  'RA_DMON_0165.png',
#  'RA_DPAR_0426.png',
#  'RA_FSLU_0568.png',
#  'RA_CBPS_0508.png',
#  'RA_PSNF_1054.png',
#  'RA_EINC_0934.png',
#  'RA_FPEC_0421.png',
#  'RA_AVTU_0104.png',
#  'RA_FGRA_0335.png',
#  'RA_PLAU_1618.png',
#  'RA_CEUO_1086.png',
#  'RA_GSTA_1921.png',
#  'RA_DMON_0978.png',
#  'RA_GPRO_1769.png',
#  'RA_LVCF_0931.png',
#  'RA_ADNM_0863.png',
#  'RA_GPRI_1831.png',
#  'RA_NJAK_0402.png',
#  'RA_AMID_0044.png',
#  'RA_BVIT_0166.png',
#  'RA_SEBA_1178.png',
#  'RA_CCOC_0244.png',
#  'RA_HLMO_0846.png',
#  'RA_FPRU_0411.png',
#  'RA_GOMS_2087.png',
#  'RA_CEUO_1085.png',
#  'RA_ECAE_0569.png',
#  'RA_NANT_0043.png',
#  'RA_HLMO_0859.png',
#  'RA_SPUP_1210.png',
#  'RA_NXAS_0055.png',
#  'RA_GAUG_1102.png',
#  'RA_CAEX_0164.png',
#  'RA_HPDA_0832.png',
#  'RA_NGRE_0374.png',
#  'RA_DMON_0500.png',
#  'RA_ADNM_0855.png',
#  'RA_EBIL_0876.png',
#  'RA_NGOT_0365.png',
#  'RA_GITA_1365.png',
#  'RA_EMIN_0961.png',
#  'RA_DMON_0926.png',
#  'RA_NGER_0351.png',
#  'RA_CSLP_0348.png',
#  'RA_NULA_1104.png',
#  'RA_PACA_1035.png',
#  'RA_ESUM_0803.png',
#  'RA_PSBV_1017.png',
#  'RA_COPL_1239.png',
#  'RA_CSIL_0217.png',
#  'RA_DPAR_0428.png',
#  'RA_CNTH_1158.png',
#  'RA_NCAT_0162.png',
#  'RA_GOLD_1601.png',
#  'RA_PTDU_1387.png',
#  'RA_CSIL_0225.png',
#  'RA_DMON_0840.png',
#  'RA_ECKR_0769.png',
#  'RA_RABB_0924.png',
#  'RA_NXAS_0054.png',
#  'RA_GELG_1302.png',
#  'RA_APED_0084.png',
#  'RA_HARC_0581.png',
#  'RA_AINA_0017.png',
#  'RA_GPHQ_2225.png',
#  'RA_DMON_0587.png',
#  'RA_GPLI_2270.png',
#  'RA_MCIR_0600.png',
#  'RA_GPAR_1713.png',
#  'RA_PPLC_1114.png',
#  'RA_CMED_0243.png',
#  'RA_GVST_2058.png',
#  'RA_PLBI_1362.png',
#  'RA_PRBS_0709.png',
#  'RA_NGOT_0361.png',
#  'RA_SSMI_1338.png',
#  'RA_SPUP_1213.png',
#  'RA_CCOS_0141.png',
#  'RA_PSRE_1645.png',
#  'RA_EMIN_0958.png',
#  'RA_EBIL_0874.png',
#  'RA_BBRE_0090.png',
#  'RA_GOMS_2111.png',
#  'RA_FPEC_0466.png',
#  'RA_ENMI_0586.png',
#  'RA_GPRO_1778.png',
#  'RA_HARC_0576.png',
#  'RA_NCTT_0194.png',
#  'RA_CLNT_1109.png',
#  'RA_PPSC_0680.png',
#  'RA_GAGU_1035.png',
#  'RA_PBSC_0925.png',
#  'RA_HVEN_0883.png',
#  'RA_NKOT_0417.png',
#  'RA_FFBI_0533.png',
#  'RA_FSLU_0559.png',
#  'RA_DMON_0929.png',
#  'RA_EISL_0956.png',
#  'RA_DOCU_0401.png',
#  'RA_DMON_0580.png',
#  'RA_LVCF_0954.png',
#  'RA_HTHU_0901.png',
#  'RA_STOV_0776.png',
#  'RA_GACC_0702.png',
#  'RA_NASP_0844.png',
#  'RA_ENMI_0620.png',
#  'RA_CLNT_1126.png',
#  'RA_GEVA_0974.png',
#  'RA_GOLC_1684.png',
#  'RA_PULA_0713.png',
#  'RA_SSTM_1272.png',
#  'RA_NDCM_1012.png',
#  'RA_AUPU_0051.png',
#  'RA_LHUN_1341.png',
#  'RA_CPOL_0260.png',
#  'RA_NCTE_0256.png',
#  'RA_COPL_1242.png',
#  'RA_GCUN_1194.png',
#  'RA_MCIR_0593.png',
#  'RA_GACU_1013.png',
#  'RA_DMON_1014.png',
#  'RA_PDAO_1555.png',
#  'RA_RABB_0943.png',
#  'RA_FSBH_0606.png',
#  'RA_LMUT_0877.png',
#  'RA_PTCO_1490.png',
#  'RA_GOLC_1690.png',
#  'RA_CDTG_0193.png',
#  'RA_PLHU_1511.png',
#  'RA_DCOF_0311.png',
#  'RA_ESUD_0989.png',
#  'RA_NCTE_0268.png',
#  'RA_GPRI_1830.png',
#  'RA_GCUV_1236.png',
#  'RA_PTCO_1501.png',
#  'RA_NCAT_0147.png',
#  'RA_FVAU_0509.png',
#  'RA_GCUN_1212.png',
#  'RA_ADRI_0810.png',
#  'RA_GAGV_1083.png',
#  'RA_RSIN_2305.png',
#  'RA_AUAJ_0016.png',
#  'RA_PRUM_0976.png',
#  'RA_AUGR_0025.png',
#  'RA_FFVI_0549.png',
#  'RA_ENVE_0710.png',
#  'RA_CCOC_0243.png',
#  'RA_ANSS_0054.png',
#  'RA_RSIN_2313.png',
#  'RA_GCBC_1279.png',
#  'RA_PBIO_1526.png',
#  'RA_SSVE_0753.png',
#  'RA_STSE_1321.png',
#  'RA_BNEG_0131.png',
#  'RA_FPEC_0465.png',
#  'RA_CTWE_0079.png',
#  'RA_DMON_0588.png',
#  'RA_GAUG_1109.png',
#  'RA_GPHQ_2224.png',
#  'RA_CDUB_0091.png',
#  'RA_GMIN_1541.png',
#  'RA_PSRE_1624.png',
#  'RA_MCIR_0589.png',
#  'RA_GMIN_1536.png',
#  'RA_HALS_0916.png',
#  'RA_STSI_1327.png',
#  'RA_NCAT_0170.png',
#  'RA_COPL_1221.png',
#  'RA_PAPR_1124.png',
#  'RA_BRUT_0059.png',
#  'RA_PTLA_1466.png',
#  'RA_ADLA_0768.png',
#  'RA_CSIL_0214.png',
#  'RA_PULA_0723.png',
#  'RA_PDAO_1546.png',
#  'RA_EOCO_0468.png',
#  'RA_DMON_0846.png',
#  'RA_DEHR_0062.png',
#  'RA_APEL_0049.png',
#  'RA_ECPM_0796.png',
#  'RA_GACC_0698.png',
#  'RA_NROS_0578.png',
#  'RA_HCAP_0805.png',
#  'RA_DMON_0993.png',
#  'RA_CPAR_0299.png',
#  'RA_CAEX_0167.png',
#  'RA_NCTO_0293.png',
#  'RA_NNOV_0472.png',
#  'RA_NDEA_0304.png',
#  'RA_NDMB_1030.png',
#  'RA_FCRO_0290.png',
#  'RA_ESUM_0809.png',
#  'RA_NCTO_0284.png',
#  'RA_ADMS_0017.png',
#  'RA_MPMI_0990.png',
#  'RA_GELG_1329.png',
#  'RA_ENVE_0683.png',
#  'RA_ADEX_0692.png',
#  'RA_PLAU_1589.png',
#  'RA_ENVE_0691.png',
#  'RA_ADGL_0706.png',
#  'RA_GOMS_2117.png',
#  'RA_DOCU_0386.png',
#  'RA_GOMS_2098.png',
#  'RA_ENNG_0627.png',
#  'RA_CNDI_1129.png',
#  'RA_CATE_0211.png',
#  'RA_NASP_0869.png',
#  'RA_EULA_1268.png',
#  'RA_GEVA_0968.png',
#  'RA_NTRI_0696.png',
#  'RA_LNIV_0914.png',
#  'RA_LMUT_0907.png',
#  'RA_CNTH_1155.png',
#  'RA_SEBA_1180.png',
#  'RA_DMON_0557.png',
#  'RA_NVEN_0767.png',
#  'RA_CBPS_0514.png',
#  'RA_DEHR_0051.png',
#  ...]

# %%
def check_dirs(filename):
    if not os.path.exists(os.path.dirname(filename)):
        try:
            os.makedirs(os.path.dirname(filename))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
    
def get_selected_taxons(file_path, inv=False):
    selected_taxons = {}
    f = open(file_path, 'r') 
    lines = f.readlines() 
    del lines[0]
    for line in lines:
        line = line.strip()
        taxon, taxon_id = line.split(',')[0], int(line.split(',')[1])
        selected_taxons[taxon] = taxon_id
    if inv:
        return {v: k for k, v in selected_taxons.items()} 
    else:
        return selected_taxons
    
def delete_all_files_in_folder(folder):
    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
files = [f for f in listdir(DATASET_PATH) if isfile(join(DATASET_PATH, f))]
for file in files:
    DATASET_PATH_img = join(DATASET_PATH_ROOT + '/' + file)

    angle = random.randint(0,180)
    print(angle)
    #img, mask_rot, mask_erod, fond_moyen = rot_image_path(DATASET_PATH,angle)
    img = cv2.imread(DATASET_PATH_img,cv2.COLOR_BGR2GRAY)
    zslack = flou_plane(img,alpha=10 )
    angle = random.randint(0,90)
    print(angle)

    for i in range(6):
        img = rot_image_img(zslack[i],angle)
    #p = plt.imshow(Image.fromarray(img))
    #plt.show()
